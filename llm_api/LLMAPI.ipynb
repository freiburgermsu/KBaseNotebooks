# %% [markdown]
# # Configure KBase Jupyter Dev Environment
# <sub><sup>(contact chenry@anl.gov with questions)</sub></sup>

# %%
# %run llm_api.py
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
# Out:
# python version 3.9.13
# KBBaseModules 0.0.1
# 1711434212.734174 INFO: Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 1711434212.734771 INFO: NumExpr defaulting to 8 threads.
# modelseedpy 0.3.3
# cobrakbase 0.3.1
# Output files printed to:/Users/chenry/code/notebooks/KBaseNotebooks/llm_api/nboutput when using KBDevUtils.output_dir
# ModelSEED: /Users/chenry/code//kb_sdk/run_local/workdir/tmp/

# %% [markdown]
# # Testing new LLM API for protein homology

# %%
import time

genome = util.msrecon.get_msgenome("151253/GCF_000005845.2.RAST")
input = {"sequences": [],"threshold": 0.9,"max_hits": 10,"discard_embeddings":True}

for ftr in genome.features:
    if ftr.protein_translation and len(ftr.protein_translation) > 0:
        input["sequences"].append({"id": ftr.id,"sequence": ftr.protein_translation})
    if len(input["sequences"]) >= 200:
        break

# Start the timer
start_time = time.time()
output = util.similarity(input)
print(output)
records = []
for item in output["proteins"]:
    if len(item["Hits"]) > 0:
        record = {"id": item["QueryId"],"total_hits": item["total_hits"],"hitid": item["Hits"][0]["HitID"],"score": item["Hits"][0]["Score"]}
        records.append(record)
df = pd.DataFrame.from_records(records)
print(df)

# End the timer
end_time = time.time()
# Calculate the elapsed time
elapsed_time = end_time - start_time
print(f'The code took {elapsed_time} seconds to run.')
# Out:
# {'proteins': [{'QueryId': 'b0001', 'Embedding': [], 'total_hits': 10, 'Hits': [{'HitID': 'B1XBC6', 'Score': 0.9998950958251953, 'Embedding': []}, {'HitID': 'P0AD87', 'Score': 0.9998950958251953, 'Embedding': []}, {'HitID': 'A7ZVW0', 'Score': 0.9998950958251953, 'Embedding': []}, {'HitID': 'P0C5Z1', 'Score': 0.9998950958251953, 'Embedding': []}, {'HitID': 'P0AD86', 'Score': 0.9998950958251953, 'Embedding': []}, {'HitID': 'B7NH81', 'Score': 0.9998950958251953, 'Embedding': []}, {'HitID': 'B6HYZ8', 'Score': 0.9998950958251953, 'Embedding': []}, {'HitID': 'Q1RGK3', 'Score': 0.9998950958251953, 'Embedding': []}, {'HitID': 'Q0TLY8', 'Score': 0.9998950958251953, 'Embedding': []}, {'HitID': 'C4ZPS8', 'Score': 0.9998950958251953, 'Embedding': []}]}, {'QueryId': 'b0002', 'Embedding': [], 'total_hits': 10, 'Hits': [{'HitID': 'P00561', 'Score': 0.9997223615646362, 'Embedding': []}, {'HitID': 'P27725', 'Score': 0.998143196105957, 'Embedding': []}, {'HitID': 'P44505', 'Score': 0.9922533631324768, 'Embedding': []}, {'HitID': 'C6DI81', 'Score': 0.9824562072753906, 'Embedding': []}, {'HitID': 'Q6DAR1', 'Score': 0.9817205667495728, 'Embedding': []}, {'HitID': 'Q46808', 'Score': 0.9809412360191345, 'Embedding': []}, {'HitID': 'B1LME7', 'Score': 0.9806305170059204, 'Embedding': []}, {'HitID': 'Q8FFG4', 'Score': 0.9805665612220764, 'Embedding': []}, {'HitID': 'B7LBJ5', 'Score': 0.9803852438926697, 'Embedding': []}, {'HitID': 'B6I6Q4', 'Score': 0.9803836345672607, 'Embedding': []}]}, {'QueryId': 'b0003', 'Embedding': [], 'total_hits': 10, 'Hits': [{'HitID': 'Q83MH9', 'Score': 0.9985261559486389, 'Embedding': []}, {'HitID': 'Q0T8I5', 'Score': 0.9985261559486389, 'Embedding': []}, {'HitID': 'B7UI48', 'Score': 0.9985228776931763, 'Embedding': []}, {'HitID': 'B7M9R6', 'Score': 0.9985228776931763, 'Embedding': []}, {'HitID': 'A7ZH92', 'Score': 0.9985228776931763, 'Embedding': []}, {'HitID': 'B7L4C8', 'Score': 0.9985228776931763, 'Embedding': []}, {'HitID': 'Q32KB5', 'Score': 0.9985212087631226, 'Embedding': []}, {'HitID': 'Q326L9', 'Score': 0.9985212087631226, 'Embedding': []}, {'HitID': 'B2U219', 'Score': 0.9985212087631226, 'Embedding': []}, {'HitID': 'P00547', 'Score': 0.9985209703445435, 'Embedding': []}]}, {'QueryId': 'b0004', 'Embedding': [], 'total_hits': 10, 'Hits': [{'HitID': 'P00934', 'Score': 0.9992974996566772, 'Embedding': []}, {'HitID': 'P27735', 'Score': 0.9966939091682434, 'Embedding': []}, {'HitID': 'P44503', 'Score': 0.9949996471405029, 'Embedding': []}, {'HitID': 'P66901', 'Score': 0.9773463010787964, 'Embedding': []}, {'HitID': 'P66899', 'Score': 0.9773463010787964, 'Embedding': []}, {'HitID': 'P66900', 'Score': 0.9773463010787964, 'Embedding': []}, {'HitID': 'Q1CHC4', 'Score': 0.9744362831115723, 'Embedding': []}, {'HitID': 'A4TK60', 'Score': 0.9744362831115723, 'Embedding': []}, {'HitID': 'Q66BQ4', 'Score': 0.9741074442863464, 'Embedding': []}, {'HitID': 'A7FJ17', 'Score': 0.9741074442863464, 'Embedding': []}]}, {'QueryId': 'b0005', 'Embedding': [], 'total_hits': 10, 'Hits': [{'HitID': 'P75616', 'Score': 0.9996408224105835, 'Embedding': []}, {'HitID': 'P64542', 'Score': 0.9886723756790161, 'Embedding': []}, {'HitID': 'P64543', 'Score': 0.9886723756790161, 'Embedding': []}, {'HitID': 'P64544', 'Score': 0.9884368777275085, 'Embedding': []}, {'HitID': 'B2SAT5', 'Score': 0.9697738885879517, 'Embedding': []}, {'HitID': 'Q2YKY9', 'Score': 0.9697738885879517, 'Embedding': []}, {'HitID': 'A9MC22', 'Score': 0.9697738885879517, 'Embedding': []}, {'HitID': 'P0C8N0', 'Score': 0.9697738885879517, 'Embedding': []}, {'HitID': 'A9WZ33', 'Score': 0.9694985151290894, 'Embedding': []}, {'HitID': 'A5VV34', 'Score': 0.9694985151290894, 'Embedding': []}]}, {'QueryId': 'b0006', 'Embedding': [], 'total_hits': 10, 'Hits': [{'HitID': 'P0A8I4', 'Score': 0.9988828301429749, 'Embedding': []}, {'HitID': 'Q0T8I2', 'Score': 0.9988483190536499, 'Embedding': []}, {'HitID': 'B1XBD1', 'Score': 0.9988372921943665, 'Embedding': []}, {'HitID': 'C4ZPT3', 'Score': 0.99883 ...
#         id  total_hits   hitid     score
# 0    b0001          10  B1XBC6  0.999895
# 1    b0002          10  P00561  0.999722
# 2    b0003          10  Q83MH9  0.998526
# 3    b0004          10  P00934  0.999297
# 4    b0005          10  P75616  0.999641
# ..     ...         ...     ...       ...
# 195  b0195          10  P44740  0.989941
# 196  b0196          10  P69412  0.999279
# 197  b0197          10  Q8X8V9  0.999018
# 198  b0198          10  Q8X800  0.998409
# 199  b0199          10  P63356  0.999223
#
# [200 rows x 4 columns]
# The code took 15.495162010192871 seconds to run.
